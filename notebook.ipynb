# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})

# %%
texto = "primer python YoR44 34 56"  
len(texto)  # Devuelve la longitud del texto
# Out:
# 25

# %%
texto.upper()  # Convierte el texto a mayúsculas
# Out:
# 'PRIMER PYTHON YOR44 34 56'

# %%
texto[4] # Accede al quinto carácter del texto
# Out:
# 'e'

# %%
texto.find("e")  # Busca la posición de la subcadena "Mundo"
# Out:
# 4

# %%
texto[2:7]  # Extrae una subcadena desde el índice 2 hasta el 6
# Out:
# 'imer '

# %%
texto.__dir__()  # Muestra todos los métodos y atributos del objeto text
# Out:
# ['__new__',
#  '__repr__',
#  '__hash__',
#  '__str__',
#  '__lt__',
#  '__le__',
#  '__eq__',
#  '__ne__',
#  '__gt__',
#  '__ge__',
#  '__iter__',
#  '__mod__',
#  '__rmod__',
#  '__len__',
#  '__getitem__',
#  '__add__',
#  '__mul__',
#  '__rmul__',
#  '__contains__',
#  'encode',
#  'replace',
#  'split',
#  'rsplit',
#  'join',
#  'capitalize',
#  'casefold',
#  'title',
#  'center',
#  'count',
#  'expandtabs',
#  'find',
#  'partition',
#  'index',
#  'ljust',
#  'lower',
#  'lstrip',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rstrip',
#  'rpartition',
#  'splitlines',
#  'strip',
#  'swapcase',
#  'translate',
#  'upper',
#  'startswith',
#  'endswith',
#  'removeprefix',
#  'removesuffix',
#  'isascii',
#  'islower',
#  'isupper',
#  'istitle',
#  'isspace',
#  'isdecimal',
#  'isdigit',
#  'isnumeric',
#  'isalpha',
#  'isalnum',
#  'isidentifier',
#  'isprintable',
#  'zfill',
#  'format',
#  'format_map',
#  '__format__',
#  'maketrans',
#  '__sizeof__',
# ...

# %%
help(texto.encode)
# Out:
# Help on built-in function encode:
#
# encode(encoding='utf-8', errors='strict') method of builtins.str instance
#     Encode the string using the codec registered for encoding.
#
#     encoding
#       The encoding in which to encode the string.
#     errors
#       The error handling scheme to use for encoding errors.
#       The default is 'strict' meaning that encoding errors raise a
#       UnicodeEncodeError.  Other possible values are 'ignore', 'replace' and
#       'xmlcharrefreplace' as well as any other name registered with
#       codecs.register_error that can handle UnicodeEncodeErrors.

# %%
email = input("Ingrese su correo electrónico: ")

if "@" not in email:
    print("Error: El email debe contener @")
elif "." not in email:
    print("Error: El email debe contener un punto")
elif email.count("@") != 1:
    print("Error: El email debe contener solamente una @")
elif (email.find(".") - 1) != email.find("@"):
    print("Error: Debe existir un punto después de la @")
else:
    # Extraer el dominio (después del punto)
    dominio = email.split(".")[-1]
    if len(dominio) < 2 or len(dominio) > 3 or dominio not in ["com", "org", "es"]:
        print("Error: El dominio debe tener entre 2 y 3 caracteres")
    else:
        print("Email válido")
# Out:
# Error: El email debe contener @

# %%
help(texto.split)
# Out:
# Help on built-in function split:
#
# split(sep=None, maxsplit=-1) method of builtins.str instance
#     Return a list of the substrings in the string, using sep as the separator string.
#
#       sep
#         The separator used to split the string.
#
#         When set to None (the default value), will split on any whitespace
#         character (including \n \r \t \f and spaces) and will discard
#         empty strings from the result.
#       maxsplit
#         Maximum number of splits.
#         -1 (the default value) means no limit.
#
#     Splitting starts at the front of the string and works to the end.
#
#     Note, str.split() is mainly useful for data that has been intentionally
#     delimited.  With natural text that includes punctuation, consider using
#     the regular expression module.

# %%
listanumeros = []
numero = 0

while numero != -1:
    numero = int(input('Ingrese un número: '))
    if numero != -1:
        listanumeros.append(numero)

# %%
listanumeros
# Out:
# [22, 33, 44, 55]

# %%
type(listanumeros)
# Out:
# list

# %%
suma = 0
for n in listanumeros:
    suma += n
print('La suma de los números ingresados es:', suma)
# Out:
# La suma de los números ingresados es: 154

# %%
conteo = len(listanumeros)
print('La cantidad de números ingresados es:', conteo)

numeros_pares = [n for n in listanumeros if n % 2 == 0]
print('Números pares ingresados:', numeros_pares)

numeros_impares = [n for n in listanumeros if n % 2 != 0]
print('Números impares ingresados:', numeros_impares)
# Out:
# La cantidad de números ingresados es: 4
# Números pares ingresados: [22, 44]
# Números impares ingresados: [33, 55]

# %%
sssss= 55

# %%
www = range(sssss)

# %%
www.index(54)
# Out:
# 54

# %%
from oracledbConection import coneccion

# %%
cursor = coneccion.cursor()
sql = 'select max(doctor_no)+1 as maximo from doctor'
cursor.execute(sql)
row = cursor.fetchone()

# %%
type(row)
# Out:
# tuple

# %%
row[0]
# Out:
# 983
